# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/Full_Data.csv')
df = df.drop(columns=['Unnamed: 0'])
df.rename(columns={'Prop_a':"Prop_a_1",
                   "Prop_b":"Prop_b_1",
                   "Prop_x":"Prop_x_1"}, inplace=True)

# %%
# Define the desired column order
new_order = ['Name', 'R_a', 'Prop_a_1', 'Prop_a_2', 'R_b', 'Prop_b_1', 'Prop_b_2', 'Prop_b_3','R_x', 
             'Prop_x_1', 'Prop_x_2', 'Tolerance_Factor', 'Structure_of_Material', 'BandGap']

# Reorder the columns
df = df[new_order]

# %%
df[df["Prop_b_2"] != 0]
# Out:
#                           Name   R_a  Prop_a_1  Prop_a_2       R_b  Prop_b_1  \
# 63        Cs2AgBi0.25In0.75Br6  1.81       1.0       0.0  2.135000      0.50
# 64   Cs2AgBi0.25In0.5Sb0.25Br6  1.81       1.0       0.0  2.302500      0.50
# 113       Cs2AgBi0.75Sb0.25Br6  1.81       1.0       0.0  2.212500      0.50
# 114     Cs2AgBi0.625Sb0.375Br6  1.81       1.0       0.0  2.318750      0.65
# 151         Cs2AgSb0.5In0.5Cl6  1.81       1.0       0.0  2.570000      0.50
# 155   Cs2Ag(Bi0.625Sb0.375)Br6  1.81       1.0       0.0  2.570000      0.50
# 179   Cs2(AgBi0.625Sb0.375)Br6  1.81       1.0       0.0  1.159375      0.50
# 180                 Cs2AgBiBr6  1.81       1.0       0.0  1.000000      0.50
# 181       Cs2AgBi0.25In0.75Br6  1.81       1.0       0.0  1.067500      0.50
# 196  Cs2AgBi0.25In0.5Sb0.25Br6  1.81       1.0       0.0  1.151250      0.50
# 197  Cs2AgBi0.25In0.5Sb0.25Br6  1.81       1.0       0.0  0.000000      0.00
# 216       Cs2BiAg0.75Cu0.25Cl6  1.81       1.0       0.0  0.858125      0.50
# 217     Cs2BiAg0.875Cu0.125Cl6  1.81       1.0       0.0  0.965625      0.50
# 218                     CsSnI3  1.81       1.0       0.0  0.690000      1.00
# 227  Cs2Ag(Bi0.625Sb0.375)Br6   1.81       1.0       0.0  1.159375      0.50
# 237      CsAg(Bi0.75In0.25)Br6  1.81       1.0       0.0  1.106250      0.50
# 238   Cs2Ag(Bi0.875Sb0.125)Br6  1.81       1.0       0.0  1.053125      0.50
# 260     Cs2AgBi0.625Sb0.375Br6  1.81       1.0       0.0  1.159375      0.50
# 301            MA3Bi1.5In0.5I9  2.16       1.0       0.0  1.500000      0.75
#
#      Prop_b_2  Prop_b_3   R_x  Prop_x_1  Prop_x_2  Tolerance_Factor  \
# 63      0.250     0.250  1.96       1.0       0.0          0.650987
# 64      0.250     0.250  1.96       1.0       0.0          0.625406
# 113     0.750    -0.250  1.96       1.0       0.0          0.638896
# 114     0.625    -0.275  1.96       1.0       0.0          0.623031
# 151     0.500     0.000  1.81       1.0       0.0          0.584412
# 155     0.625    -0.125  1.96       1.0       0.0          0.588475
# 179     0.625    -0.125  1.96       1.0       0.0          0.831571
# 180     1.000    -0.500  1.96       1.0       0.0          0.861869
# 181     0.250     0.250  1.96       1.0       0.0          0.848772
# 196     0.250     0.250  1.96       1.0       0.0          0.833064
# 197     0.500     0.500  0.00       0.0       1.0          1.279863
# 216     0.750    -0.250  1.81       1.0       0.0          0.886747
# 217     0.750    -0.250  1.81       1.0       0.0          0.863995
# 218     0.875    -0.875  2.20       1.0       0.0          0.931645
# 227     0.625    -0.125  1.96       1.0       0.0          0.831571
# 237     0.750    -0.250  1.96       1.0       0.0          0.841431
# 238     0.875    -0.375  1.96       1.0       0.0          0.851527
# 260     0.625    -0.125  1.96       1.0       0.0          0.831571
# 301     1.000    -0.750  2.10       1.0       0.0          0.980000
#
#      Structure_of_Material  BandGap
# 63                       2     1.85
# 64                       2     1.50
# 113                      2     1.58
# 114                      2     1.86
# 151                      2     2.81
# 155                      2     1.86
# 179                      1     1.86
# 180                      1     2.12
# 181                      1     2.27
# 196                      1     1.50
# 197                      4     1.67
# 216                      1     1.60
# 217                      1     1.90
# 218                      0     1.27
# 227                      1     1.86
# 237                      1     1.80
# 238                      1     1.80
# 260                      1     1.87
# 301                      0     2.10

# %%
df
# Out:
#                  Name   R_a  Prop_a_1  Prop_a_2   R_b  Prop_b_1  Prop_b_2  \
# 0              MAPbI3  2.16       1.0       0.0  1.19      1.00       0.0
# 1              MAPbI3  2.16       1.0       0.0  1.19      1.00       0.0
# 2              MAPbI3  2.16       1.0       0.0  1.19      1.00       0.0
# 3              CsPbI3  1.81       1.0       0.0  1.19      1.00       0.0
# 4              CsPbI3  1.81       1.0       0.0  1.19      1.00       0.0
# ..                ...   ...       ...       ...   ...       ...       ...
# 298  CsGe(I0.7Br0.3)3  1.81       1.0       0.0  0.53      1.00       0.0
# 299   CsZn0.2Pb0.8Cl3  1.81       1.0       0.0  1.10      0.20       0.0
# 300           RbInCl3  1.72       1.0       0.0  0.80      1.00       0.0
# 301   MA3Bi1.5In0.5I9  2.16       1.0       0.0  1.50      0.75       1.0
# 302          Cs2InCl6  1.81       1.0       0.0  0.80      1.00       0.0
#
#      Prop_b_3    R_x  Prop_x_1  Prop_x_2  Tolerance_Factor  \
# 0        0.00  2.200       1.0       0.0          0.909435
# 1        0.00  2.200       1.0       0.0          0.909435
# 2        0.00  2.200       1.0       0.0          0.909435
# 3        0.00  2.200       1.0       0.0          0.836430
# 4        0.00  2.200       1.0       0.0          0.836430
# ..        ...    ...       ...       ...               ...
# 298      0.00  2.128       0.7       0.3          0.967042
# 299      0.80  1.810       1.0       0.0          0.837146
# 300      0.00  1.810       1.0       0.0          1.520280
# 301     -0.75  2.100       1.0       0.0          0.980000
# 302      0.00  1.810       1.0       0.0          1.590000
#
#      Structure_of_Material  BandGap
# 0                        0    1.550
# 1                        0    1.550
# 2                        0    1.550
# 3                        1    1.730
# 4                        1    1.730
# ..                     ...      ...
# 298                      0    0.830
# 299                      1    3.144
# 300                      4    3.250
# 301                      0    2.100
# 302                      4    2.800
#
# [301 rows x 14 columns]

# %%
df['Prop_a_2'] = 1 - df['Prop_a_1']
df['Prop_b_3'] = 1 - df['Prop_b_1'] - df['Prop_b_2']
df['Prop_x_2'] = 1 - df['Prop_x_1']

# %%
df = df.dropna()

# %%
df.to_csv('../Data/Full_Data_ranamed_columns.csv', index=False)

# %%
# example = {
#     "Name": ["Ba3CsGa5Se10Cl2"],#"Cs2AgBi0.25In0.5Sb0.25Br6"],
#     "R_a": [2.16],
#     "Prop_a_1": [1],
#     "Prop_a_2": [0],
#     "R_b": [1.19],
#     "Prop_b_1": [1],
#     "Prop_b_2": [0],
#     "Prop_b_3": [0],
#     "R_x": [2.2],
#     "Prop_x_1": [1],
#     "Prop_x_2": [0],
#     "BandGap": [1.55],
#     "Tolerance_Factor": [0.909435270198628],
#     "Structure_of_Material": [0],
# }

# %%
df.isnull().sum()
# Out:
# Name                     0
# R_a                      0
# Prop_a_1                 0
# Prop_a_2                 0
# R_b                      0
# Prop_b_1                 0
# Prop_b_2                 0
# Prop_b_3                 0
# R_x                      0
# Prop_x_1                 0
# Prop_x_2                 0
# Tolerance_Factor         0
# Structure_of_Material    0
# BandGap                  0
# dtype: int64
